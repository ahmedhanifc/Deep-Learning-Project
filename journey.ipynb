# %% [markdown]
# <img src = "runs/run_2_20251122_020743/loss_curve.png" style = "width:700px; display: inline-block;">
#
# <img src = "runs/run_2_20251122_020743/accuracy_curve.png" style = "width:700px; display: inline-block;">

# %% [markdown]
# <img src = "runs/run_1_20251127_174614/loss_curve.png" style = "width:1000px">
#
# <div style = "blue">
#     I am underfitting here
# </div>

# %% [raw]
# {
#   "hyperparameters": {
#     "learning_rate": 0.001,
#     "batch_size": 32,
#     "epochs": 60,
#     "hidden_sizes": [
#       512,
#       256,
#       128
#     ],
#     "dropout_rates": [
#       0.5,
#       0.5,
#       0.4
#     ],
#     "weight_decay": 0.0001,
#     "notes": "Learning Rate Added adaptive"
#   },
#   "model_config": {
#     "batch_size": 32,
#     "learning_rate": 0.001,
#     "epochs": 60,
#     "device": "cpu",
#     "weight_decay": 0.0001,
#     "patience": 5,
#     "delta": 0.01,
#     "best_val_loss": Infinity,
#     "no_improvement_count": 0
#   },
#   "architecture_config": {
#     "input_size": 150528,
#     "hidden_sizes": [
#       512,
#       256,
#       128
#     ],
#     "num_classes": 4,
#     "dropout_rates": [
#       0.5,
#       0.5,
#       0.4
#     ]
#   },
#   "transform_config": {
#     "image_size": [
#       224,
#       224
#     ],
#     "normalize_mean": [
#       0.485,
#       0.456,
#       0.406
#     ],
#     "normalize_std": [
#       0.229,
#       0.224,
#       0.225
#     ],
#     "random_horizontal_flip_prob": 0.5,
#     "random_rotation_degrees": 15
#   }
# }

# %% [markdown]
# <img src = "runs/run_1_20251127_222008/loss_curve.png" style = "width:700px; display: inline-block;">
#
# <img src = "runs/run_1_20251127_222008/accuracy_curve.png" style = "width:700px; display: inline-block;">
#
# overfitting again

# %% [markdown]
# <img src = "runs/run_2_20251127_224256/loss_curve.png" style = "width:700px; display: inline-block;">
#
# <img src = "runs/run_2_20251127_224256/accuracy_curve.png" style = "width:700px; display: inline-block;">
#
# Better not overfitting. Can see test loss stagnating. Will increase model input size

# %% [raw]
# {
#   "hyperparameters": {
#     "learning_rate": 0.0005,
#     "batch_size": 32,
#     "epochs": 60,
#     "hidden_sizes": [
#       256,
#       128,
#       64
#     ],
#     "dropout_rates": [
#       0.6,
#       0.5,
#       0.5
#     ],
#     "weight_decay": 0.01,
#     "notes": "Narrow MLP with High Regularization",
#     "input_size": 12288,
#     "image_size": [
#       64,
#       64
#     ]
#   },
#   "model_config": {
#     "batch_size": 32,
#     "learning_rate": 0.0005,
#     "epochs": 60,
#     "device": "cpu",
#     "weight_decay": 0.01,
#     "patience": 5,
#     "delta": 0.01,
#     "best_val_loss": Infinity,
#     "no_improvement_count": 0
#   },
#   "architecture_config": {
#     "input_size": 12288,
#     "hidden_sizes": [
#       256,
#       128,
#       64
#     ],
#     "num_classes": 4,
#     "dropout_rates": [
#       0.6,
#       0.5,
#       0.5
#     ]
#   },
#   "transform_config": {
#     "image_size": [
#       64,
#       64
#     ],
#     "normalize_mean": [
#       0.485,
#       0.456,
#       0.406
#     ],
#     "normalize_std": [
#       0.229,
#       0.224,
#       0.225
#     ],
#     "random_horizontal_flip_prob": 0.5,
#     "random_rotation_degrees": 15
#   }
# }

# %% [markdown]
# Breakthrough... this was really goooood. it went till 50 epochs with early stopping. just issue is its underfitting now
#
#
# <img src = "runs/run_1_20251129_201029/loss_curve.png" style = "width:700px; display: inline-block;">
#
# <img src = "runs/run_1_20251129_201029/accuracy_curve.png" style = "width:700px; display: inline-block;">

# %% [markdown]
# {
#   "hyperparameters": {
#     "learning_rate": 0.0005,
#     "batch_size": 32,
#     "epochs": 100,
#     "hidden_sizes": [
#       128,
#       64,
#       32
#     ],
#     "dropout_rates": [
#       0.4,
#       0.4,
#       0.3
#     ],
#     "weight_decay": 0.1,
#     "notes": "Narrow MLP with High Regularization",
#     "image_size": [
#       64,
#       64
#     ],
#     "early_stopping": {
#       "patience": 10,
#       "min_delta": 0.0009,
#       "mode": "min",
#       "restore_best_weights": true
#     }
#   },
#   "model_config": {
#     "batch_size": 32,
#     "learning_rate": 0.0005,
#     "epochs": 100,
#     "device": "cpu",
#     "weight_decay": 0.1,
#     "patience": 5,
#     "delta": 0.01,
#     "best_val_loss": Infinity,
#     "no_improvement_count": 0
#   },
#   "architecture_config": {
#     "input_size": 12288,
#     "hidden_sizes": [
#       128,
#       64,
#       32
#     ],
#     "num_classes": 4,
#     "dropout_rates": [
#       0.4,
#       0.4,
#       0.3
#     ]
#   },
#   "transform_config": {
#     "image_size": [
#       64,
#       64
#     ],
#     "normalize_mean": [
#       0.485,
#       0.456,
#       0.406
#     ],
#     "normalize_std": [
#       0.229,
#       0.224,
#       0.225
#     ],
#     "random_horizontal_flip_prob": 0.5,
#     "random_rotation_degrees": 15,
#     "color_jitter_brightness": 0.2,
#     "color_jitter_contrast": 0.2,
#     "color_jitter_saturation": 0.2,
#     "random_resized_crop_size": [
#       64,
#       64
#     ],
#     "random_resized_crop_scale": [
#       0.8,
#       1.0
#     ],
#     "random_resized_crop_ratio": [
#       0.75,
#       1.33
#     ]
#   }
# }
