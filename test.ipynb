# %%
import pandas as pd

# %%
pd.read_csv("model_runs.csv")
# Out:
#                   run_id                     run_dir  \
# 0  run_1_20251122_013835  runs\run_1_20251122_013835
# 1  run_2_20251122_020743  runs\run_2_20251122_020743
# 2  run_3_20251122_030954  runs\run_3_20251122_030954
#
#                     timestamp  total_time_seconds  learning_rate  batch_size  \
# 0  2025-11-22T02:07:43.440864         1739.403414         0.0010          64
# 1  2025-11-22T03:09:54.427515         3724.741818         0.0001          32
# 2  2025-11-22T05:38:49.635664         8924.781317         0.0005          64
#
#    epochs      hidden_sizes    dropout_rates  input_size  ...  train_loss  \
# 0      50   [512, 256, 128]  [0.3, 0.3, 0.2]      150528  ...    0.816108
# 1     100   [512, 256, 128]  [0.2, 0.2, 0.2]      150528  ...    0.149609
# 2      75  [1024, 512, 256]  [0.5, 0.4, 0.3]      150528  ...    0.826593
#
#    train_accuracy  train_f1_macro  train_precision_macro  train_recall_macro  \
# ...
